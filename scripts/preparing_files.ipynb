# %% [markdown]
# # Creating necessary files for library

# %% [markdown]
# ## Weight files
#
# CMS provides the coefficients for the categories in a SAS CPORT file, which is a proprietary file format not documented openly by SAS. Thus, the only
# way to see the coefficients (also referred to as weights) for the categories is use the Final Announcement documents that contain the weights in tables. The announcement documents can be
# found on [CMS's website](https://www.cms.gov/medicare/payment/medicare-advantage-rates-statistics/announcements-and-documents)
#
# One important things to be aware of is that when CMS uses the same model in for multiple years without any coefficient changes, they do not republish the information in each year's announcement document. Thus, you must go back to the first time the model was used to find the information. To help make it concrete, consider the CMS Model Version V24. It was first used in Payment Year (PY) 2020 and is seen in the [2020 Final Notice](https://www.cms.gov/medicare/health-plans/medicareadvtgspecratestats/announcements-and-documents-items/2020announcement). It was also used in [PY 2021](https://www.cms.gov/medicarehealth-plansmedicareadvtgspecratestatsannouncements-and-documents/2021-0), [PY2022](https://www.cms.gov/medicarehealth-plansmedicareadvtgspecratestatsannouncements-and-documents/2022), [PY2023](https://www.cms.gov/medicarehealth-plansmedicareadvtgspecratestatsannouncements-and-documents/2023), etc. however none of the announcement documents linked contain coefficients for V24 as they did not change from the original implementation in 2020.
#
# To minimize manual work, the [tabula-py](https://pypi.org/project/tabula-py/) library will be used to read table objects from PDFs. It requires Java to be installed, please follow instructions linked in official documentation to get tabula-py working.
#
# Key Assumptions:
# 1. The headers of the tables are identitified and outlined in column_dict
# 2. Manual editing is sometimes still needed based on the table layout, thus output file should be checked.
# 3. Might require lots of editing/customization based on PDF

# %%
import tabula
import pandas as pd
from pathlib import Path

# Specify the path to your PDF file
file_path = Path.cwd() / 'cms_files'
pdf_file = "Announcement2020.pdf"

# Use tabula to extract tables from the PDF
# You have to open the PDF up to find the relevant pages
tables = tabula.read_pdf(file_path / pdf_file, pages="75-80", multiple_tables=True)

for i, table in enumerate(tables, start=1):
    df = table
    if i == 1:
        combined_df = df.copy()
    else:
        combined_df = pd.concat([combined_df, df], ignore_index=True)

# %%
combined_df
# Out:
#                       Unnamed: 0      Unnamed: 1         Unnamed: 2  \
# 0                            NaN        Variable  Description Label
# 1                            NaN             NaN                NaN
# 2                       Medicaid             NaN                NaN
# 3    Originally Disabled, Female             NaN                NaN
# 4      Originally Disabled, Male             NaN                NaN
# ..                           ...             ...                ...
# 150           Payment HCC Counts             NaN                NaN
# 151                           D1   1 payment HCC                  -
# 152                           D2  2 payment HCCs                  -
# 153                           D3  3 payment HCCs                  -
# 154                           D4  4 payment HCCs                  -
#
#     Community, Community,.1 Community,.2 Community,.3 Community,.4  \
# 0     NonDual,     NonDual,      FBDual,      FBDual,      PBDual,
# 1         Aged     Disabled         Aged     Disabled         Aged
# 2            -            -            -            -            -
# 3        0.250            -        0.173            -        0.136
# 4        0.147            -        0.182            -        0.083
# ..         ...          ...          ...          ...          ...
# 150        NaN          NaN          NaN          NaN          NaN
# 151          -            -            -            -            -
# 152          -            -            -            -            -
# 153          -            -            -            -            -
# 154      0.006            -            -            -            -
#
#     Community,.5     Unnamed: 3
# 0        PBDual,  Institutional
# 1       Disabled            NaN
# 2              -          0.061
# 3              -              -
# 4              -              -
# ..           ...            ...
# 150          NaN            NaN
# 151            -            NaN
# 152            -            NaN
# 153            -            NaN
# 154            -            NaN
#
# [155 rows x 10 columns]

# %%
# This may change as needed based on the headers
column_dict = {
    'Variable': 'category',
    'Description Label': 'description',
    'Community,NonDual,Aged': 'CNA',
    'Community,NonDual,Disabled': 'CND',
    'Community,FBDual,Aged': 'CFA',
    'Community,FBDual,Disabled': 'CFD',
    'Community,PBDual,Aged': 'CPA',
    'Community,PBDual,Disabled': 'CPD',
    'Institutional': 'INS'
}
final_df = (
    combined_df
    .rename(columns=lambda x: x.replace('\r', ''))
    .rename(columns=column_dict)
)
final_df['category'] = final_df.apply(lambda x: x['category'].replace('\r', ''), axis=1)
# final_df['description'] = final_df.apply(lambda x: x['description'].replace('\r', ''), axis=1)
final_df.to_csv(file_path / 'v24_weights.txt', index=False, header=True, sep='|')

# %% [markdown]
# ## Category Definition files
#
# CMS provides a SAS file that contains the category definitions (also called label definitions). However, this file only contains the category definitions for "disease HCCs", in other words HCCs that have a number. It does not contain information for demographic categories or disease interactions. These exist in other SAS files as part of the macro and need to be extracted manually.
#
# The code below reads in that file, and parses it to a YAML. It assumes the file contents look like the below.

# %% [markdown]
# ## V24 Category File

# %%
import re
import yaml
from pathlib import Path

# Define category lists
demo_category_list = [
        'F0_34', 'F35_44', 'F45_54', 'F55_59', 'F60_64',
        'F65_69', 'F70_74', 'F75_79', 'F80_84', 'F85_89', 
        'F90_94', 'F95_GT', 'M0_34', 'M35_44', 'M45_54', 'M55_59', 'M60_64',
        'M65_69', 'M70_74', 'M75_79', 'M80_84', 'M85_89', 
        'M90_94', 'M95_GT'
    ]
nedemo_category_list = [
    'NEF0_34', 'NEF35_44', 'NEF45_54', 'NEF55_59', 'NEF60_64',
        'NEF65', 'NEF66', 'NEF67', 'NEF68', 'NEF69', 'NEF70_74', 
        'NEF75_79', 'NEF80_84', 'NEF85_89', 'NEF90_94', 'NEF95_GT',
        'NEM0_34', 'NEM35_44', 'NEM45_54', 'NEM55_59', 'NEM60_64',
        'NEM65', 'NEM66', 'NEM67', 'NEM68', 'NEM69', 'NEM70_74', 
        'NEM75_79', 'NEM80_84', 'NEM85_89', 'NEM90_94', 'NEM95_GT'
]
demo_interaction_dict = {
    'LTIMCAID': {'descr': 'Medicaid', 'type': 'demographic_interaction'},
    'OriginallyDisabled_Female': {'descr': 'Originally Disabled, Female', 'type': 'demographic_interaction'},
    'OriginallyDisabled_Male': {'descr': 'Originally Disabled, Male', 'type': 'demographic_interaction'}
}
disease_interaction_dict = {
    'HCC47_gCancer': {'descr': 'Immune Disorders*Cancer', 'type': 'disease_interaction'},
    'DIABETES_CHF': {'descr': 'Congestive Heart Failure*Diabetes', 'type': 'disease_interaction'},
    'CHF_gCopdCF': {'descr': 'Congestive Heart Failure*Chronic Obstructive Pulmonary Disease', 'type': 'disease_interaction'},
    'HCC85_gRenal_V24': {'descr': 'Congestive Heart Failure*Renal', 'type': 'disease_interaction'},
    'gCopdCF_CARD_RESP_FAIL': {'descr': 'Cardiorespiratory Failure*Chronic Obstructive Pulmonary Disease', 'type': 'disease_interaction'},
    'HCC85_HCC96': {'descr': 'Congestive Heart Failure*Specified Heart Arrhythmias', 'type': 'disease_interaction'},
    'gSubstanceUseDisorder_gPsych': {'descr': 'Substance Use Disorder*Psychiatric', 'type': 'disease_interaction'},
    'SEPSIS_PRESSURE_ULCER': {'descr': 'Sepsis*Pressure Ulcer', 'type': 'disease_interaction'},
    'SEPSIS_ARTIF_OPENINGS': {'descr': 'Sepsis*Artificial Openings for Feeding or Elimination', 'type': 'disease_interaction'},
    'ART_OPENINGS_PRESS_ULCER': {'descr': 'Artificial Openings for Feeding or Elimination*Pressure Ulcer', 'type': 'disease_interaction'},
    'gCopdCF_ASP_SPEC_B_PNEUM': {'descr': 'Chronic Obstructive Pulmonary Disease*Aspiration and Specified Bacterial Pneumonias', 'type': 'disease_interaction'},
    'ASP_SPEC_B_PNEUM_PRES_ULC': {'descr': 'Aspiration and Specified Bacterial Pneumonias*Pressure Ulcer', 'type': 'disease_interaction'},
    'SEPSIS_ASP_SPEC_BACT_PNEUM': {'descr': 'Sepsis*Aspiration and Specified Bacterial Pneumonias', 'type': 'disease_interaction'},
    'SCHIZOPHRENIA_gCopdCF': {'descr': 'Schizophrenia*Chronic Obstructive Pulmonary Disease', 'type': 'disease_interaction'},
    'SCHIZOPHRENIA_CHF': {'descr': 'Schizophrenia*Congestive Heart Failure', 'type': 'disease_interaction'},
    'SCHIZOPHRENIA_SEIZURES': {'descr': 'Schizophrenia*Seizure Disorders and Convulsions', 'type': 'disease_interaction'},
    'DISABLED_HCC85': {'descr': 'Disabled, Congestive Heart Failure', 'type': 'disease_interaction'},
    'DISABLED_PRESSURE_ULCER': {'descr': 'Disabled, Pressure Ulcer', 'type': 'disease_interaction'},
    'DISABLED_HCC161': {'descr': 'Disabled, Chronic Ulcer of the Skin, Except Pressure Ulcer', 'type': 'disease_interaction'},
    'DISABLED_HCC39': {'descr': 'Disabled, Bone/Joint Muscle Infections/Necrosis', 'type': 'disease_interaction'},
    'DISABLED_HCC77': {'descr': 'Disabled, Multiple Sclerosis', 'type': 'disease_interaction'},
    'DISABLED_HCC6': {'descr': 'Disabled, Opportunistic Infections', 'type': 'disease_interaction'},
}

cat_dict = {}
demo_category_dict = {}
demo_pttrn = r'[MF]\d{1,2}_?|[MF]6[5-9]|OriginallyDisabled_[MF]|LTIMCAID|ORIGDS'

# Helper function
def replace_chars(input_string, chars_to_replace, replacement):
    for char in chars_to_replace:
        input_string = input_string.replace(char, replacement)
    return input_string
    
# Get demo categories
for category in demo_category_list:
    x = re.search(demo_pttrn, category)
    # print(type(x.group(0)))
    # print(x.group(0))
    # print(x.group(0)[-1])
    first_age = replace_chars(x.group(0), ['F', 'M', '_'], '')
    last_age = category[category.find('_')+1:]
    if category.startswith('F'):
        gender = 'Female'
    else:
        gender = 'Male'
    if last_age == 'GT':
        demo_category_dict[category] = {'descr': f'{gender}, {first_age} Years old or Over', 'type': 'demographic'}
    else:
        demo_category_dict[category] = {'descr': f'{gender}, {first_age} to {last_age} Years old', 'type': 'demographic'}

for category in nedemo_category_list:
    x = re.search(demo_pttrn, category)
    # print(type(x.group(0)))
    # print(x.group(0))
    # print(x.group(0)[-1])
    first_age = replace_chars(x.group(0), ['F', 'M', '_'], '')
    last_age = category[category.find('_')+1:]
    if category.startswith('NEF'):
        gender = 'Female'
    else:
        gender = 'Male'
    if last_age == 'GT':
        demo_category_dict[category] = {'descr': f'New Enrollee, {gender}, {first_age} Years old or Over', 'type': 'demographic'}
    else:
        if 'NE' in last_age:
            demo_category_dict[category] = {'descr': f'New Enrollee, {gender}, {first_age} Years old', 'type': 'demographic'}
        else:
            demo_category_dict[category] = {'descr': f'New Enrollee, {gender}, {first_age} to {last_age} Years old', 'type': 'demographic'}
        

# update cat dict
cat_dict.update(demo_category_dict)
cat_dict.update(demo_interaction_dict)
cat_dict.update(disease_interaction_dict)

# %%
# Disease categories

# This assumes the file is in the current directory, change to the appropriate location
file_path = Path.cwd() / 'cms_files'
# Will need to change the below as appropriate
input_file_name = 'V24H86L1.txt'
output_file_name = 'v24_category_definition.yaml'

with open(file_path / input_file_name, mode="r") as file:
    lines = file.readlines()
hcc_cat_dict = {}

for line in lines:
    cat_code = re.search(r'HCC\d+', line)
    if cat_code:
        s = re.split(r'HCC\d+', line)
        descr = s[1].replace('=', '').replace('"', "").strip()
        number = cat_code[0].split('HCC')[1]
        hcc_cat_dict[cat_code[0]] = {
            'descr': descr, 
            'number': int(number),
            'type': 'disease'
        }

cat_dict.update(hcc_cat_dict)



cat_dict
# Out:
# {'F0_34': {'descr': 'Female, 0 to 34 Years old', 'type': 'demographic'},
#  'F35_44': {'descr': 'Female, 35 to 44 Years old', 'type': 'demographic'},
#  'F45_54': {'descr': 'Female, 45 to 54 Years old', 'type': 'demographic'},
#  'F55_59': {'descr': 'Female, 55 to 59 Years old', 'type': 'demographic'},
#  'F60_64': {'descr': 'Female, 60 to 64 Years old', 'type': 'demographic'},
#  'F65_69': {'descr': 'Female, 65 to 69 Years old', 'type': 'demographic'},
#  'F70_74': {'descr': 'Female, 70 to 74 Years old', 'type': 'demographic'},
#  'F75_79': {'descr': 'Female, 75 to 79 Years old', 'type': 'demographic'},
#  'F80_84': {'descr': 'Female, 80 to 84 Years old', 'type': 'demographic'},
#  'F85_89': {'descr': 'Female, 85 to 89 Years old', 'type': 'demographic'},
#  'F90_94': {'descr': 'Female, 90 to 94 Years old', 'type': 'demographic'},
#  'F95_GT': {'descr': 'Female, 95 Years old or Over', 'type': 'demographic'},
#  'M0_34': {'descr': 'Male, 0 to 34 Years old', 'type': 'demographic'},
#  'M35_44': {'descr': 'Male, 35 to 44 Years old', 'type': 'demographic'},
#  'M45_54': {'descr': 'Male, 45 to 54 Years old', 'type': 'demographic'},
#  'M55_59': {'descr': 'Male, 55 to 59 Years old', 'type': 'demographic'},
#  'M60_64': {'descr': 'Male, 60 to 64 Years old', 'type': 'demographic'},
#  'M65_69': {'descr': 'Male, 65 to 69 Years old', 'type': 'demographic'},
#  'M70_74': {'descr': 'Male, 70 to 74 Years old', 'type': 'demographic'},
#  'M75_79': {'descr': 'Male, 75 to 79 Years old', 'type': 'demographic'},
#  'M80_84': {'descr': 'Male, 80 to 84 Years old', 'type': 'demographic'},
#  'M85_89': {'descr': 'Male, 85 to 89 Years old', 'type': 'demographic'},
#  'M90_94': {'descr': 'Male, 90 to 94 Years old', 'type': 'demographic'},
#  'M95_GT': {'descr': 'Male, 95 Years old or Over', 'type': 'demographic'},
#  'NEF0_34': {'descr': 'New Enrollee, Female, 0 to 34 Years old',
#   'type': 'demographic'},
#  'NEF35_44': {'descr': 'New Enrollee, Female, 35 to 44 Years old',
#   'type': 'demographic'},
#  'NEF45_54': {'descr': 'New Enrollee, Female, 45 to 54 Years old',
#   'type': 'demographic'},
#  'NEF55_59': {'descr': 'New Enrollee, Female, 55 to 59 Years old',
#   'type': 'demographic'},
#  'NEF60_64': {'descr': 'New Enrollee, Female, 60 to 64 Years old',
#   'type': 'demographic'},
#  'NEF65': {'descr': 'New Enrollee, Female, 65 Years old',
#   'type': 'demographic'},
#  'NEF66': {'descr': 'New Enrollee, Female, 66 Years old',
#   'type': 'demographic'},
#  'NEF67': {'descr': 'New Enrollee, Female, 67 Years old',
#   'type': 'demographic'},
#  'NEF68': {'descr': 'New Enrollee, Female, 68 Years old',
#   'type': 'demographic'},
#  'NEF69': {'descr': 'New Enrollee, Female, 69 Years old',
#   'type': 'demographic'},
#  'NEF70_74': {'descr': 'New Enrollee, Female, 70 to 74 Years old',
#   'type': 'demographic'},
#  'NEF75_79': {'descr': 'New Enrollee, Female, 75 to 79 Years old',
#   'type': 'demographic'},
#  'NEF80_84': {'descr': 'New Enrollee, Female, 80 to 84 Years old',
#   'type': 'demographic'},
#  'NEF85_89': {'descr': 'New Enrollee, Female, 85 to 89 Years old',
#   'type': 'demographic'},
#  'NEF90_94': {'descr': 'New Enrollee, Female, 90 to 94 Years old',
#   'type': 'demographic'},
#  'NEF95_GT': {'descr': 'New Enrollee, Female, 95 Years old or Over',
#   'type': 'demographic'},
#  'NEM0_34': {'descr': 'New Enrollee, Male, 0 to 34 Years old',
#   'type': 'demographic'},
#  'NEM35_44': {'descr': 'New Enrollee, Male, 35 to 44 Years old',
#   'type': 'demographic'},
#  'NEM45_54': {'descr': 'New Enrollee, Male, 45 to 54 Years old',
#   'type': 'demographic'},
#  'NEM55_59': {'descr': 'New Enrollee, Male, 55 to 59 Years old',
#   'type': 'demographic'},
#  'NEM60_64': {'descr': 'New Enrollee, Male, 60 to 64 Years old',
#   'type': 'demographic'},
#  'NEM65': {'descr': 'New Enrollee, Male, 65 Years old', 'type': 'demographic'},
#  'NEM66': {'descr': 'New Enrollee, Male, 66 Years old', 'type': 'demographic'},
#  'NEM67': {'descr': 'New Enrollee, Male, 67 Years old', 'type': 'demographic'},
#  'NEM68': {'descr': 'New Enrollee, Male, 68 Years old', 'type': 'demographic'},
#  'NEM69': {'descr': 'New Enrollee, Male, 69 Years old', 'type': 'demographic'},
#  'NEM70_74': {'descr': 'New Enrollee, Male, 70 to 74 Years old',
#   'type': 'demographic'},
#  'NEM75_79': {'descr': 'New Enrollee, Male, 75 to 79 Years old',
#   'type': 'demographic'},
#  'NEM80_84': {'descr': 'New Enrollee, Male, 80 to 84 Years old',
#   'type': 'demographic'},
#  'NEM85_89': {'descr': 'New Enrollee, Male, 85 to 89 Years old',
#   'type': 'demographic'},
#  'NEM90_94': {'descr': 'New Enrollee, Male, 90 to 94 Years old',
#   'type': 'demographic'},
#  'NEM95_GT': {'descr': 'New Enrollee, Male, 95 Years old or Over',
#   'type': 'demographic'},
#  'LTIMCAID': {'descr': 'Medicaid', 'type': 'demographic_interaction'},
#  'OriginallyDisabled_Female': {'descr': 'Originally Disabled, Female',
#   'type': 'demographic_interaction'},
#  'OriginallyDisabled_Male': {'descr': 'Originally Disabled, Male',
#   'type': 'demographic_interaction'},
#  'HCC47_gCancer': {'descr': 'Immune Disorders*Cancer',
#   'type': 'disease_interaction'},
#  'DIABETES_CHF': {'descr': 'Congestive Heart Failure*Diabetes',
#   'type': 'disease_interaction'},
#  'CHF_gCopdCF': {'descr': 'Congestive Heart Failure*Chronic Obstructive Pulmonary Disease',
#   'type': 'disease_interaction'},
#  'HCC85_gRenal_V24': {'descr': 'Congestive Heart Failure*Renal',
#   'type': 'disease_interaction'},
#  'gCopdCF_CARD_RESP_FAIL': {'descr': 'Cardiorespiratory Failure*Chronic Obstructive Pulmonary Disease',
#   'type': 'disease_interaction'},
#  'HCC85_HCC96': {'descr': 'Congestive Heart Failure*Specified Heart Arrhythmias',
#   'type': 'disease_interaction'},
#  'gSubstanceUseDisorder_gPsych': {'descr': 'Substance Use Disorder*Psychiatric',
#   'type': 'disease_interaction'},
#  'SEPSIS_PRESSURE_ULCER': {'descr': 'Sepsis*Pressure Ulcer',
#   'type': 'disease_interaction'},
#  'SEPSIS_ARTIF_OPENINGS': {'descr': 'Sepsis*Artificial Openings for Feeding or Elimination',
#   'type': 'disease_interaction'},
#  'ART_OPENINGS_PRESS_ULCER': {'descr': 'Artificial Openings for Feeding or Elimination*Pressure Ulcer',
#   'type': 'disease_interaction'},
#  'gCopdCF_ASP_SPEC_B_PNEUM': {'descr': 'Chronic Obstructive Pulmonary Disease*Aspiration and Specified Bacterial Pneumonias',
#   'type': 'disease_interaction'},
#  'ASP_SPEC_B_PNEUM_PRES_ULC': {'descr': 'Aspiration and Specified Bacterial Pneumonias*Pressure Ulcer',
#   'type': 'disease_interaction'},
#  'SEPSIS_ASP_SPEC_BACT_PNEUM': {'descr': 'Sepsis*Aspiration and Specified Bacterial Pneumonias',
#   'type': 'disease_interaction'},
#  'SCHIZOPHRENIA_gCopdCF': {'descr': 'Schizophrenia*Chronic Obstructive Pulmonary Disease',
#   'type': 'disease_interaction'},
#  'SCHIZOPHRENIA_CHF': {'descr': 'Schizophrenia*Congestive Heart Failure',
#   'type': 'disease_interaction'},
#  'SCHIZOPHRENIA_SEIZURES': {'descr': 'Schizophrenia*Seizure Disorders and Convulsions',
#   'type': 'disease_interaction'},
#  'DISABLED_HCC85': {'descr': 'Disabled, Congestive Heart Failure',
#   'type': 'disease_interaction'},
#  'DISABLED_PRESSURE_ULCER': {'descr': 'Disabled, Pressure Ulcer',
#   'type': 'disease_interaction'},
#  'DISABLED_HCC161': {'descr': 'Disabled, Chronic Ulcer of the Skin, Except Pressure Ulcer',
#   'type': 'disease_interaction'},
#  'DISABLED_HCC39': {'descr': 'Disabled, Bone/Joint Muscle Infections/Necrosis',
#   'type': 'disease_interaction'},
#  'DISABLED_HCC77': {'descr': 'Disabled, Multiple Sclerosis',
#   'type': 'disease_interaction'},
#  'DISABLED_HCC6': {'descr': 'Disabled, Opportunistic Infections',
#   'type': 'disease_interaction'},
#  'HCC1': {'descr': 'HIV/AIDS', 'number': 1, 'type': 'disease'},
#  'HCC2': {'descr': 'Septicemia, Sepsis, Systemic Inflammatory Response Syndrome/Shock',
#   'number': 2,
#   'type': 'disease'},
#  'HCC6': {'descr': 'Opportunistic Infections', 'number': 6, 'type': 'disease'},
#  'HCC8': {'descr': 'Metastatic Cancer and Acute Leukemia',
#   'number': 8,
#   'type': 'disease'},
#  'HCC9': {'descr': 'Lung and Other Severe Cancers',
#   'number': 9,
#   'type': 'disease'},
#  'HCC10': {'descr': 'Lymphoma and Other Cancers',
#   'number': 10,
#   'type': 'disease'},
#  'HCC11': {'descr': 'Colorectal, Bladder, and Other Cancers',
#   'number': 11,
#   'type': 'disease'},
#  'HCC12': {'descr': 'Breast, Prostate, and Other Cancers and Tumors',
#   'number': 12,
#   'type': 'disease'},
#  'HCC17': {'descr': 'Diabetes with Acute Complications',
#   'number': 17,
#   'type': 'disease'},
#  'HCC18': {'descr': 'Diabetes with Chronic Complications',
#   'number': 18,
#   'type': 'disease'},
#  'HCC19': {'descr': 'Diabetes without Complication',
#   'number': 19,
#   'type': 'disease'},
#  'HCC21': {'descr': 'Protein-Calorie Malnutrition',
#   'number': 21,
#   'type': 'disease'},
#  'HCC22': {'descr': 'Morbid Obesity', 'number': 22, 'type': 'disease'},
#  'HCC23': {'descr': 'Other Significant Endocrine and Metabolic Disorders',
#   'number': 23,
#   'type': 'disease'},
#  'HCC27': {'descr': 'End-Stage Liver Disease',
#   'number': 27,
#   'type': 'disease'},
#  'HCC28': {'descr': 'Cirrhosis of Liver', 'number': 28, 'type': 'disease'},
#  'HCC29': {'descr': 'Chronic Hepatitis', 'number': 29, 'type': 'disease'},
#  'HCC33': {'descr': 'Intestinal Obstruction/Perforation',
#   'number': 33,
#   'type': 'disease'},
#  'HCC34': {'descr': 'Chronic Pancreatitis', 'number': 34, 'type': 'disease'},
#  'HCC35': {'descr': 'Inflammatory Bowel Disease',
#   'number': 35,
#   'type': 'disease'},
#  'HCC39': {'descr': 'Bone/Joint/Muscle Infections/Necrosis',
#   'number': 39,
#   'type': 'disease'},
#  'HCC40': {'descr': 'Rheumatoid Arthritis and Inflammatory Connective Tissue Disease',
#   'number': 40,
#   'type': 'disease'},
#  'HCC46': {'descr': 'Severe Hematological Disorders',
#   'number': 46,
#   'type': 'disease'},
#  'HCC47': {'descr': 'Disorders of Immunity', 'number': 47, 'type': 'disease'},
#  'HCC48': {'descr': 'Coagulation Defects and Other Specified Hematological Disorders',
#   'number': 48,
#   'type': 'disease'},
#  'HCC51': {'descr': 'Dementia With Complications',
#   'number': 51,
#   'type': 'disease'},
#  'HCC52': {'descr': 'Dementia Without Complication',
#   'number': 52,
#   'type': 'disease'},
#  'HCC54': {'descr': 'Substance Use with Psychotic Complications',
#   'number': 54,
#   'type': 'disease'},
#  'HCC55': {'descr': 'Substance Use Disorder, Moderate/Severe, or Substance Use with Complications',
#   'number': 55,
#   'type': 'disease'},
#  'HCC56': {'descr': 'Substance Use Disorder, Mild, Except Alcohol and Cannabis',
#   'number': 56,
#   'type': 'disease'},
#  'HCC57': {'descr': 'Schizophrenia', 'number': 57, 'type': 'disease'},
#  'HCC58': {'descr': 'Reactive and Unspecified Psychosis',
#   'number': 58,
#   'type': 'disease'},
#  'HCC59': {'descr': 'Major Depressive, Bipolar, and Paranoid Disorders',
#   'number': 59,
#   'type': 'disease'},
#  'HCC60': {'descr': 'Personality Disorders', 'number': 60, 'type': 'disease'},
#  'HCC70': {'descr': 'Quadriplegia', 'number': 70, 'type': 'disease'},
#  'HCC71': {'descr': 'Paraplegia', 'number': 71, 'type': 'disease'},
#  'HCC72': {'descr': 'Spinal Cord Disorders/Injuries',
#   'number': 72,
#   'type': 'disease'},
#  'HCC73': {'descr': 'Amyotrophic Lateral Sclerosis and Other Motor Neuron Disease',
#   'number': 73,
#   'type': 'disease'},
#  'HCC74': {'descr': 'Cerebral Palsy', 'number': 74, 'type': 'disease'},
#  'HCC75': {'descr': 'Myasthenia Gravis/Myoneural Disorders and Guillain-Barre Syndrome/Inflammatory and Toxic Neuropathy',
#   'number': 75,
#   'type': 'disease'},
#  'HCC76': {'descr': 'Muscular Dystrophy', 'number': 76, 'type': 'disease'},
#  'HCC77': {'descr': 'Multiple Sclerosis', 'number': 77, 'type': 'disease'},
#  'HCC78': {'descr': "Parkinson's and Huntington's Diseases",
#   'number': 78,
#   'type': 'disease'},
#  'HCC79': {'descr': 'Seizure Disorders and Convulsions',
#   'number': 79,
#   'type': 'disease'},
#  'HCC80': {'descr': 'Coma, Brain Compression/Anoxic Damage',
#   'number': 80,
#   'type': 'disease'},
#  'HCC82': {'descr': 'Respirator Dependence/Tracheostomy Status',
#   'number': 82,
#   'type': 'disease'},
#  'HCC83': {'descr': 'Respiratory Arrest', 'number': 83, 'type': 'disease'},
#  'HCC84': {'descr': 'Cardio-Respiratory Failure and Shock',
#   'number': 84,
#   'type': 'disease'},
#  'HCC85': {'descr': 'Congestive Heart Failure',
#   'number': 85,
#   'type': 'disease'},
#  'HCC86': {'descr': 'Acute Myocardial Infarction',
#   'number': 86,
#   'type': 'disease'},
#  'HCC87': {'descr': 'Unstable Angina and Other Acute Ischemic Heart Disease',
#   'number': 87,
#   'type': 'disease'},
#  'HCC88': {'descr': 'Angina Pectoris', 'number': 88, 'type': 'disease'},
#  'HCC96': {'descr': 'Specified Heart Arrhythmias',
#   'number': 96,
#   'type': 'disease'},
#  'HCC99': {'descr': 'Intracranial Hemorrhage',
#   'number': 99,
#   'type': 'disease'},
#  'HCC100': {'descr': 'Ischemic or Unspecified Stroke',
#   'number': 100,
#   'type': 'disease'},
#  'HCC103': {'descr': 'Hemiplegia/Hemiparesis',
#   'number': 103,
#   'type': 'disease'},
#  'HCC104': {'descr': 'Monoplegia, Other Paralytic Syndromes',
#   'number': 104,
#   'type': 'disease'},
#  'HCC106': {'descr': 'Atherosclerosis of the Extremities with Ulceration or Gangrene',
#   'number': 106,
#   'type': 'disease'},
#  'HCC107': {'descr': 'Vascular Disease with Complications',
#   'number': 107,
#   'type': 'disease'},
#  'HCC108': {'descr': 'Vascular Disease', 'number': 108, 'type': 'disease'},
#  'HCC110': {'descr': 'Cystic Fibrosis', 'number': 110, 'type': 'disease'},
#  'HCC111': {'descr': 'Chronic Obstructive Pulmonary Disease',
#   'number': 111,
#   'type': 'disease'},
#  'HCC112': {'descr': 'Fibrosis of Lung and Other Chronic Lung Disorders',
#   'number': 112,
#   'type': 'disease'},
#  'HCC114': {'descr': 'Aspiration and Specified Bacterial Pneumonias',
#   'number': 114,
#   'type': 'disease'},
#  'HCC115': {'descr': 'Pneumococcal Pneumonia, Empyema, Lung Abscess',
#   'number': 115,
#   'type': 'disease'},
#  'HCC122': {'descr': 'Proliferative Diabetic Retinopathy and Vitreous Hemorrhage',
#   'number': 122,
#   'type': 'disease'},
#  'HCC124': {'descr': 'Exudative Macular Degeneration',
#   'number': 124,
#   'type': 'disease'},
#  'HCC134': {'descr': 'Dialysis Status', 'number': 134, 'type': 'disease'},
#  'HCC135': {'descr': 'Acute Renal Failure', 'number': 135, 'type': 'disease'},
#  'HCC136': {'descr': 'Chronic Kidney Disease, Stage 5',
#   'number': 136,
#   'type': 'disease'},
#  'HCC137': {'descr': 'Chronic Kidney Disease, Severe (Stage 4)',
#   'number': 137,
#   'type': 'disease'},
#  'HCC138': {'descr': 'Chronic Kidney Disease, Moderate (Stage 3)',
#   'number': 138,
#   'type': 'disease'},
#  'HCC157': {'descr': 'Pressure Ulcer of Skin with Necrosis Through to Muscle, Tendon, or Bone',
#   'number': 157,
#   'type': 'disease'},
#  'HCC158': {'descr': 'Pressure Ulcer of Skin with Full Thickness Skin Loss',
#   'number': 158,
#   'type': 'disease'},
#  'HCC159': {'descr': 'Pressure Ulcer of Skin with Partial Thickness Skin Loss',
#   'number': 159,
#   'type': 'disease'},
#  'HCC161': {'descr': 'Chronic Ulcer of Skin, Except Pressure',
#   'number': 161,
#   'type': 'disease'},
#  'HCC162': {'descr': 'Severe Skin Burn or Condition',
#   'number': 162,
#   'type': 'disease'},
#  'HCC166': {'descr': 'Severe Head Injury', 'number': 166, 'type': 'disease'},
#  'HCC167': {'descr': 'Major Head Injury', 'number': 167, 'type': 'disease'},
#  'HCC169': {'descr': 'Vertebral Fractures without Spinal Cord Injury',
#   'number': 169,
#   'type': 'disease'},
#  'HCC170': {'descr': 'Hip Fracture/Dislocation',
#   'number': 170,
#   'type': 'disease'},
#  'HCC173': {'descr': 'Traumatic Amputations and Complications',
#   'number': 173,
#   'type': 'disease'},
#  'HCC176': {'descr': 'Complications of Specified Implanted Device or Graft',
#   'number': 176,
#   'type': 'disease'},
#  'HCC186': {'descr': 'Major Organ Transplant or Replacement Status',
#   'number': 186,
#   'type': 'disease'},
#  'HCC188': {'descr': 'Artificial Openings for Feeding or Elimination',
#   'number': 188,
#   'type': 'disease'},
#  'HCC189': {'descr': 'Amputation Status, Lower Limb/Amputation Complications',
#   'number': 189,
#   'type': 'disease'}}

# %%
import json
with open(file_path / "v24_category.json", "w") as json_file:
    json.dump(cat_dict, json_file)

# %% [markdown]
# ## V28 Category File

# %%
import re
import yaml
from pathlib import Path

# Define category lists
demo_category_list = [
        'F0_34', 'F35_44', 'F45_54', 'F55_59', 'F60_64',
        'F65_69', 'F70_74', 'F75_79', 'F80_84', 'F85_89', 
        'F90_94', 'F95_GT', 'M0_34', 'M35_44', 'M45_54', 'M55_59', 'M60_64',
        'M65_69', 'M70_74', 'M75_79', 'M80_84', 'M85_89', 
        'M90_94', 'M95_GT'
    ]
nedemo_category_list = [
    'NEF0_34', 'NEF35_44', 'NEF45_54', 'NEF55_59', 'NEF60_64',
        'NEF65', 'NEF66', 'NEF67', 'NEF68', 'NEF69', 'NEF70_74', 
        'NEF75_79', 'NEF80_84', 'NEF85_89', 'NEF90_94', 'NEF95_GT',
        'NEM0_34', 'NEM35_44', 'NEM45_54', 'NEM55_59', 'NEM60_64',
        'NEM65', 'NEM66', 'NEM67', 'NEM68', 'NEM69', 'NEM70_74', 
        'NEM75_79', 'NEM80_84', 'NEM85_89', 'NEM90_94', 'NEM95_GT'
]
demo_interaction_dict = {
    'LTIMCAID': {'descr': 'Medicaid', 'type': 'demographic_interaction'},
    'OriginallyDisabled_Female': {'descr': 'Originally Disabled, Female', 'type': 'demographic_interaction'},
    'OriginallyDisabled_Male': {'descr': 'Originally Disabled, Male', 'type': 'demographic_interaction'}
}
disease_interaction_dict = {
    'DIABETES_HF_V28': {'descr': 'Diabetes*Heart Failure', 'type': 'disease_interaction'},
    'HF_CHR_LUNG_V28': {'descr': 'Heart Failure*Chronic Lung Disorder', 'type': 'disease_interaction'},
    'HF_KIDNEY_V28': {'descr': 'Heart Failure*Kidney', 'type': 'disease_interaction'},
    'CHR_LUNG_CARD _RESP_FAIL_V28': {'descr': 'Chronic Lung Disorder*Cardiorespiratory Failure', 'type': 'disease_interaction'},
    'HF_HCC238_V28': {'descr': 'Cardiorespiratory Failure*Chronic Obstructive Pulmonary Disease', 'type': 'disease_interaction'},
    'gSubUseDisorder_gPsych_V28': {'descr': 'Substance Use Disorder*Psychiatric', 'type': 'disease_interaction'},
    'DISABLED_CANCER_V28': {'descr': 'Disabled, Cancer', 'type': 'disease_interaction'},
    'DISABLED_NEURO_V28': {'descr': 'Disabled, Neurological', 'type': 'disease_interaction'},
    'DISABLED_HF_V28': {'descr': 'Disabled, Heart Failure', 'type': 'disease_interaction'},
    'DISABLED_CHR_LUNG_V28': {'descr': 'Disabled, Chronic Lung Disorder', 'type': 'disease_interaction'},
    'DISABLED_ULCER_V28': {'descr': 'Disabled, Skin Ulcer', 'type': 'disease_interaction'},
    'D1': {'descr': '1 payment HCCs', 'type': 'disease_count'},
    'D2': {'descr': '2 payment HCCs', 'type': 'disease_count'},
    'D3': {'descr': '3 payment HCCs', 'type': 'disease_count'},
    'D4': {'descr': '4 payment HCCs', 'type': 'disease_count'},
    'D5': {'descr': '5 payment HCCs', 'type': 'disease_count'},
    'D6': {'descr': '6 payment HCCs', 'type': 'disease_count'},
    'D7': {'descr': '7 payment HCCs', 'type': 'disease_count'},
    'D8': {'descr': '8 payment HCCs', 'type': 'disease_count'},
    'D9': {'descr': '9 payment HCCs', 'type': 'disease_count'},
    'D10P': {'descr': '10 or more payment HCCs', 'type': 'disease_count'},
}

cat_dict = {}
demo_category_dict = {}
demo_pttrn = r'[MF]\d{1,2}_?|[MF]6[5-9]|OriginallyDisabled_[MF]|LTIMCAID|ORIGDS'

# Helper function
def replace_chars(input_string, chars_to_replace, replacement):
    for char in chars_to_replace:
        input_string = input_string.replace(char, replacement)
    return input_string
    
# Get demo categories
for category in demo_category_list:
    x = re.search(demo_pttrn, category)
    # print(type(x.group(0)))
    # print(x.group(0))
    # print(x.group(0)[-1])
    first_age = replace_chars(x.group(0), ['F', 'M', '_'], '')
    last_age = category[category.find('_')+1:]
    if category.startswith('F'):
        gender = 'Female'
    else:
        gender = 'Male'
    if last_age == 'GT':
        demo_category_dict[category] = {'descr': f'{gender}, {first_age} Years old or Over', 'type': 'demographic'}
    else:
        demo_category_dict[category] = {'descr': f'{gender}, {first_age} to {last_age} Years old', 'type': 'demographic'}

for category in nedemo_category_list:
    x = re.search(demo_pttrn, category)
    # print(type(x.group(0)))
    # print(x.group(0))
    # print(x.group(0)[-1])
    first_age = replace_chars(x.group(0), ['F', 'M', '_'], '')
    last_age = category[category.find('_')+1:]
    if category.startswith('NEF'):
        gender = 'Female'
    else:
        gender = 'Male'
    if last_age == 'GT':
        demo_category_dict[category] = {'descr': f'New Enrollee, {gender}, {first_age} Years old or Over', 'type': 'demographic'}
    else:
        if 'NE' in last_age:
            demo_category_dict[category] = {'descr': f'New Enrollee, {gender}, {first_age} Years old', 'type': 'demographic'}
        else:
            demo_category_dict[category] = {'descr': f'New Enrollee, {gender}, {first_age} to {last_age} Years old', 'type': 'demographic'}
        

# update cat dict
cat_dict.update(demo_category_dict)
cat_dict.update(demo_interaction_dict)
cat_dict.update(disease_interaction_dict)

# %%
# Disease categories

# This assumes the file is in the current directory, change to the appropriate location
file_path = Path.cwd() / 'cms_files'
# Will need to change the below as appropriate
input_file_name = 'V28115L3.txt'

with open(file_path / input_file_name, mode="r") as file:
    lines = file.readlines()
hcc_cat_dict = {}

for line in lines:
    cat_code = re.search(r'HCC\d+', line)
    if cat_code:
        s = re.split(r'HCC\d+', line)
        descr = s[1].replace('=', '').replace('"', "").strip()
        number = cat_code[0].split('HCC')[1]
        hcc_cat_dict[cat_code[0]] = {
            'descr': descr, 
            'number': int(number),
            'type': 'disease'
        }

cat_dict.update(hcc_cat_dict)

# %%
cat_dict
# Out:
# {'F0_34': {'descr': 'Female, 0 to 34 Years old', 'type': 'demographic'},
#  'F35_44': {'descr': 'Female, 35 to 44 Years old', 'type': 'demographic'},
#  'F45_54': {'descr': 'Female, 45 to 54 Years old', 'type': 'demographic'},
#  'F55_59': {'descr': 'Female, 55 to 59 Years old', 'type': 'demographic'},
#  'F60_64': {'descr': 'Female, 60 to 64 Years old', 'type': 'demographic'},
#  'F65_69': {'descr': 'Female, 65 to 69 Years old', 'type': 'demographic'},
#  'F70_74': {'descr': 'Female, 70 to 74 Years old', 'type': 'demographic'},
#  'F75_79': {'descr': 'Female, 75 to 79 Years old', 'type': 'demographic'},
#  'F80_84': {'descr': 'Female, 80 to 84 Years old', 'type': 'demographic'},
#  'F85_89': {'descr': 'Female, 85 to 89 Years old', 'type': 'demographic'},
#  'F90_94': {'descr': 'Female, 90 to 94 Years old', 'type': 'demographic'},
#  'F95_GT': {'descr': 'Female, 95 Years old or Over', 'type': 'demographic'},
#  'M0_34': {'descr': 'Male, 0 to 34 Years old', 'type': 'demographic'},
#  'M35_44': {'descr': 'Male, 35 to 44 Years old', 'type': 'demographic'},
#  'M45_54': {'descr': 'Male, 45 to 54 Years old', 'type': 'demographic'},
#  'M55_59': {'descr': 'Male, 55 to 59 Years old', 'type': 'demographic'},
#  'M60_64': {'descr': 'Male, 60 to 64 Years old', 'type': 'demographic'},
#  'M65_69': {'descr': 'Male, 65 to 69 Years old', 'type': 'demographic'},
#  'M70_74': {'descr': 'Male, 70 to 74 Years old', 'type': 'demographic'},
#  'M75_79': {'descr': 'Male, 75 to 79 Years old', 'type': 'demographic'},
#  'M80_84': {'descr': 'Male, 80 to 84 Years old', 'type': 'demographic'},
#  'M85_89': {'descr': 'Male, 85 to 89 Years old', 'type': 'demographic'},
#  'M90_94': {'descr': 'Male, 90 to 94 Years old', 'type': 'demographic'},
#  'M95_GT': {'descr': 'Male, 95 Years old or Over', 'type': 'demographic'},
#  'NEF0_34': {'descr': 'New Enrollee, Female, 0 to 34 Years old',
#   'type': 'demographic'},
#  'NEF35_44': {'descr': 'New Enrollee, Female, 35 to 44 Years old',
#   'type': 'demographic'},
#  'NEF45_54': {'descr': 'New Enrollee, Female, 45 to 54 Years old',
#   'type': 'demographic'},
#  'NEF55_59': {'descr': 'New Enrollee, Female, 55 to 59 Years old',
#   'type': 'demographic'},
#  'NEF60_64': {'descr': 'New Enrollee, Female, 60 to 64 Years old',
#   'type': 'demographic'},
#  'NEF65': {'descr': 'New Enrollee, Female, 65 Years old',
#   'type': 'demographic'},
#  'NEF66': {'descr': 'New Enrollee, Female, 66 Years old',
#   'type': 'demographic'},
#  'NEF67': {'descr': 'New Enrollee, Female, 67 Years old',
#   'type': 'demographic'},
#  'NEF68': {'descr': 'New Enrollee, Female, 68 Years old',
#   'type': 'demographic'},
#  'NEF69': {'descr': 'New Enrollee, Female, 69 Years old',
#   'type': 'demographic'},
#  'NEF70_74': {'descr': 'New Enrollee, Female, 70 to 74 Years old',
#   'type': 'demographic'},
#  'NEF75_79': {'descr': 'New Enrollee, Female, 75 to 79 Years old',
#   'type': 'demographic'},
#  'NEF80_84': {'descr': 'New Enrollee, Female, 80 to 84 Years old',
#   'type': 'demographic'},
#  'NEF85_89': {'descr': 'New Enrollee, Female, 85 to 89 Years old',
#   'type': 'demographic'},
#  'NEF90_94': {'descr': 'New Enrollee, Female, 90 to 94 Years old',
#   'type': 'demographic'},
#  'NEF95_GT': {'descr': 'New Enrollee, Female, 95 Years old or Over',
#   'type': 'demographic'},
#  'NEM0_34': {'descr': 'New Enrollee, Male, 0 to 34 Years old',
#   'type': 'demographic'},
#  'NEM35_44': {'descr': 'New Enrollee, Male, 35 to 44 Years old',
#   'type': 'demographic'},
#  'NEM45_54': {'descr': 'New Enrollee, Male, 45 to 54 Years old',
#   'type': 'demographic'},
#  'NEM55_59': {'descr': 'New Enrollee, Male, 55 to 59 Years old',
#   'type': 'demographic'},
#  'NEM60_64': {'descr': 'New Enrollee, Male, 60 to 64 Years old',
#   'type': 'demographic'},
#  'NEM65': {'descr': 'New Enrollee, Male, 65 Years old', 'type': 'demographic'},
#  'NEM66': {'descr': 'New Enrollee, Male, 66 Years old', 'type': 'demographic'},
#  'NEM67': {'descr': 'New Enrollee, Male, 67 Years old', 'type': 'demographic'},
#  'NEM68': {'descr': 'New Enrollee, Male, 68 Years old', 'type': 'demographic'},
#  'NEM69': {'descr': 'New Enrollee, Male, 69 Years old', 'type': 'demographic'},
#  'NEM70_74': {'descr': 'New Enrollee, Male, 70 to 74 Years old',
#   'type': 'demographic'},
#  'NEM75_79': {'descr': 'New Enrollee, Male, 75 to 79 Years old',
#   'type': 'demographic'},
#  'NEM80_84': {'descr': 'New Enrollee, Male, 80 to 84 Years old',
#   'type': 'demographic'},
#  'NEM85_89': {'descr': 'New Enrollee, Male, 85 to 89 Years old',
#   'type': 'demographic'},
#  'NEM90_94': {'descr': 'New Enrollee, Male, 90 to 94 Years old',
#   'type': 'demographic'},
#  'NEM95_GT': {'descr': 'New Enrollee, Male, 95 Years old or Over',
#   'type': 'demographic'},
#  'LTIMCAID': {'descr': 'Medicaid', 'type': 'demographic_interaction'},
#  'OriginallyDisabled_Female': {'descr': 'Originally Disabled, Female',
#   'type': 'demographic_interaction'},
#  'OriginallyDisabled_Male': {'descr': 'Originally Disabled, Male',
#   'type': 'demographic_interaction'},
#  'DIABETES_HF_V28': {'descr': 'Diabetes*Heart Failure',
#   'type': 'disease_interaction'},
#  'HF_CHR_LUNG_V28': {'descr': 'Heart Failure*Chronic Lung Disorder',
#   'type': 'disease_interaction'},
#  'HF_KIDNEY_V28': {'descr': 'Heart Failure*Kidney',
#   'type': 'disease_interaction'},
#  'CHR_LUNG_CARD _RESP_FAIL_V28': {'descr': 'Chronic Lung Disorder*Cardiorespiratory Failure',
#   'type': 'disease_interaction'},
#  'HF_HCC238_V28': {'descr': 'Cardiorespiratory Failure*Chronic Obstructive Pulmonary Disease',
#   'type': 'disease_interaction'},
#  'gSubUseDisorder_gPsych_V28': {'descr': 'Substance Use Disorder*Psychiatric',
#   'type': 'disease_interaction'},
#  'DISABLED_CANCER_V28': {'descr': 'Disabled, Cancer',
#   'type': 'disease_interaction'},
#  'DISABLED_NEURO_V28': {'descr': 'Disabled, Neurological',
#   'type': 'disease_interaction'},
#  'DISABLED_HF_V28': {'descr': 'Disabled, Heart Failure',
#   'type': 'disease_interaction'},
#  'DISABLED_CHR_LUNG_V28': {'descr': 'Disabled, Chronic Lung Disorder',
#   'type': 'disease_interaction'},
#  'DISABLED_ULCER_V28': {'descr': 'Disabled, Skin Ulcer',
#   'type': 'disease_interaction'},
#  'D1': {'descr': '1 payment HCCs', 'type': 'disease_count'},
#  'D2': {'descr': '2 payment HCCs', 'type': 'disease_count'},
#  'D3': {'descr': '3 payment HCCs', 'type': 'disease_count'},
#  'D4': {'descr': '4 payment HCCs', 'type': 'disease_count'},
#  'D5': {'descr': '5 payment HCCs', 'type': 'disease_count'},
#  'D6': {'descr': '6 payment HCCs', 'type': 'disease_count'},
#  'D7': {'descr': '7 payment HCCs', 'type': 'disease_count'},
#  'D8': {'descr': '8 payment HCCs', 'type': 'disease_count'},
#  'D9': {'descr': '9 payment HCCs', 'type': 'disease_count'},
#  'D10P': {'descr': '10 or more payment HCCs', 'type': 'disease_count'},
#  'HCC1': {'descr': 'HIV/AIDS', 'number': 1, 'type': 'disease'},
#  'HCC2': {'descr': 'Septicemia, Sepsis, Systemic Inflammatory Response Syndrome/Shock',
#   'number': 2,
#   'type': 'disease'},
#  'HCC6': {'descr': 'Opportunistic Infections', 'number': 6, 'type': 'disease'},
#  'HCC17': {'descr': 'Cancer Metastatic to Lung, Liver, Brain, and Other Organs; Acute Myeloid Leukemia Except Promyelocytic',
#   'number': 17,
#   'type': 'disease'},
#  'HCC18': {'descr': 'Cancer Metastatic to Bone, Other and Unspecified Metastatic Cancer; Acute Leukemia Except Myeloid',
#   'number': 18,
#   'type': 'disease'},
#  'HCC19': {'descr': 'Myelodysplastic Syndromes, Multiple Myeloma, and Other Cancers',
#   'number': 19,
#   'type': 'disease'},
#  'HCC20': {'descr': 'Lung and Other Severe Cancers',
#   'number': 20,
#   'type': 'disease'},
#  'HCC21': {'descr': 'Lymphoma and Other Cancers',
#   'number': 21,
#   'type': 'disease'},
#  'HCC22': {'descr': 'Bladder, Colorectal, and Other Cancers',
#   'number': 22,
#   'type': 'disease'},
#  'HCC23': {'descr': 'Prostate, Breast, and Other Cancers and Tumors',
#   'number': 23,
#   'type': 'disease'},
#  'HCC35': {'descr': 'Pancreas Transplant Status',
#   'number': 35,
#   'type': 'disease'},
#  'HCC36': {'descr': 'Diabetes with Severe Acute Complications',
#   'number': 36,
#   'type': 'disease'},
#  'HCC37': {'descr': 'Diabetes with Chronic Complications',
#   'number': 37,
#   'type': 'disease'},
#  'HCC38': {'descr': 'Diabetes with Glycemic, Unspecified, or No Complications',
#   'number': 38,
#   'type': 'disease'},
#  'HCC48': {'descr': 'Morbid Obesity', 'number': 48, 'type': 'disease'},
#  'HCC49': {'descr': 'Specified Lysosomal Storage Disorders',
#   'number': 49,
#   'type': 'disease'},
#  'HCC50': {'descr': 'Amyloidosis, Porphyria, and Other Specified Metabolic Disorders',
#   'number': 50,
#   'type': 'disease'},
#  'HCC51': {'descr': "Addison's and Cushing's Diseases, Acromegaly, and Other Specified Endocrine Disorders",
#   'number': 51,
#   'type': 'disease'},
#  'HCC62': {'descr': 'Liver Transplant Status/Complications',
#   'number': 62,
#   'type': 'disease'},
#  'HCC63': {'descr': 'Chronic Liver Failure/End-Stage Liver Disorders',
#   'number': 63,
#   'type': 'disease'},
#  'HCC64': {'descr': 'Cirrhosis of Liver', 'number': 64, 'type': 'disease'},
#  'HCC65': {'descr': 'Chronic Hepatitis', 'number': 65, 'type': 'disease'},
#  'HCC68': {'descr': 'Cholangitis and Obstruction of Bile Duct Without Gallstones',
#   'number': 68,
#   'type': 'disease'},
#  'HCC77': {'descr': 'Intestine Transplant Status/Complications',
#   'number': 77,
#   'type': 'disease'},
#  'HCC78': {'descr': 'Intestinal Obstruction/Perforation',
#   'number': 78,
#   'type': 'disease'},
#  'HCC79': {'descr': 'Chronic Pancreatitis', 'number': 79, 'type': 'disease'},
#  'HCC80': {'descr': "Crohn's Disease (Regional Enteritis)",
#   'number': 80,
#   'type': 'disease'},
#  'HCC81': {'descr': 'Ulcerative Colitis', 'number': 81, 'type': 'disease'},
#  'HCC92': {'descr': 'Bone/Joint/Muscle/Severe Soft Tissue Infections/Necrosis',
#   'number': 92,
#   'type': 'disease'},
#  'HCC93': {'descr': 'Rheumatoid Arthritis and Other Specified Inflammatory Rheumatic Disorders',
#   'number': 93,
#   'type': 'disease'},
#  'HCC94': {'descr': 'Systemic Lupus Erythematosus and Other Specified Systemic Connective Tissue Disorders',
#   'number': 94,
#   'type': 'disease'},
#  'HCC107': {'descr': 'Sickle Cell Anemia (Hb-SS) and Thalassemia Beta Zero',
#   'number': 107,
#   'type': 'disease'},
#  'HCC108': {'descr': 'Sickle Cell Disorders, Except Sickle Cell Anemia (Hb-SS) and Thalassemia Beta Zero; Beta Thalassemia Major',
#   'number': 108,
#   'type': 'disease'},
#  'HCC109': {'descr': 'Acquired Hemolytic, Aplastic, and Sideroblastic Anemias',
#   'number': 109,
#   'type': 'disease'},
#  'HCC111': {'descr': 'Hemophilia, Male', 'number': 111, 'type': 'disease'},
#  'HCC112': {'descr': 'Immune Thrombocytopenia and Specified Coagulation Defects and Hemorrhagic Conditions',
#   'number': 112,
#   'type': 'disease'},
#  'HCC114': {'descr': 'Common Variable and Combined Immunodeficiencies',
#   'number': 114,
#   'type': 'disease'},
#  'HCC115': {'descr': 'Specified Immunodeficiencies and White Blood Cell Disorders',
#   'number': 115,
#   'type': 'disease'},
#  'HCC125': {'descr': 'Dementia, Severe', 'number': 125, 'type': 'disease'},
#  'HCC126': {'descr': 'Dementia, Moderate', 'number': 126, 'type': 'disease'},
#  'HCC127': {'descr': 'Dementia, Mild or Unspecified',
#   'number': 127,
#   'type': 'disease'},
#  'HCC135': {'descr': 'Drug Use with Psychotic Complications',
#   'number': 135,
#   'type': 'disease'},
#  'HCC136': {'descr': 'Alcohol Use with Psychotic Complications',
#   'number': 136,
#   'type': 'disease'},
#  'HCC137': {'descr': 'Drug Use Disorder, Moderate/Severe, or Drug Use with Non-Psychotic Complications',
#   'number': 137,
#   'type': 'disease'},
#  'HCC138': {'descr': 'Drug Use Disorder, Mild, Uncomplicated, Except Cannabis',
#   'number': 138,
#   'type': 'disease'},
#  'HCC139': {'descr': 'Alcohol Use Disorder, Moderate/Severe, or Alcohol Use with Specified Non-Psychotic Complications',
#   'number': 139,
#   'type': 'disease'},
#  'HCC151': {'descr': 'Schizophrenia', 'number': 151, 'type': 'disease'},
#  'HCC152': {'descr': 'Psychosis, Except Schizophrenia',
#   'number': 152,
#   'type': 'disease'},
#  'HCC153': {'descr': 'Personality Disorders; Anorexia/Bulimia Nervosa',
#   'number': 153,
#   'type': 'disease'},
#  'HCC154': {'descr': 'Bipolar Disorders without Psychosis',
#   'number': 154,
#   'type': 'disease'},
#  'HCC155': {'descr': 'Major Depression, Moderate or Severe, without Psychosis',
#   'number': 155,
#   'type': 'disease'},
#  'HCC180': {'descr': 'Quadriplegia', 'number': 180, 'type': 'disease'},
#  'HCC181': {'descr': 'Paraplegia', 'number': 181, 'type': 'disease'},
#  'HCC182': {'descr': 'Spinal Cord Disorders/Injuries',
#   'number': 182,
#   'type': 'disease'},
#  'HCC190': {'descr': 'Amyotrophic Lateral Sclerosis and Other Motor Neuron Disease, Spinal Muscular Atrophy',
#   'number': 190,
#   'type': 'disease'},
#  'HCC191': {'descr': 'Quadriplegic Cerebral Palsy',
#   'number': 191,
#   'type': 'disease'},
#  'HCC192': {'descr': 'Cerebral Palsy, Except Quadriplegic',
#   'number': 192,
#   'type': 'disease'},
#  'HCC193': {'descr': 'Chronic Inflammatory Demyelinating Polyneuritis and Multifocal Motor Neuropathy',
#   'number': 193,
#   'type': 'disease'},
#  'HCC195': {'descr': 'Myasthenia Gravis with (Acute) Exacerbation',
#   'number': 195,
#   'type': 'disease'},
#  'HCC196': {'descr': 'Myasthenia Gravis without (Acute) Exacerbation and Other Myoneural Disorders',
#   'number': 196,
#   'type': 'disease'},
#  'HCC197': {'descr': 'Muscular Dystrophy', 'number': 197, 'type': 'disease'},
#  'HCC198': {'descr': 'Multiple Sclerosis', 'number': 198, 'type': 'disease'},
#  'HCC199': {'descr': 'Parkinson and Other Degenerative Disease of Basal Ganglia',
#   'number': 199,
#   'type': 'disease'},
#  'HCC200': {'descr': 'Friedreich and Other Hereditary Ataxias; Huntington Disease',
#   'number': 200,
#   'type': 'disease'},
#  'HCC201': {'descr': 'Seizure Disorders and Convulsions',
#   'number': 201,
#   'type': 'disease'},
#  'HCC202': {'descr': 'Coma, Brain Compression/Anoxic Damage',
#   'number': 202,
#   'type': 'disease'},
#  'HCC211': {'descr': 'Respirator Dependence/Tracheostomy Status/Complications',
#   'number': 211,
#   'type': 'disease'},
#  'HCC212': {'descr': 'Respiratory Arrest', 'number': 212, 'type': 'disease'},
#  'HCC213': {'descr': 'Cardio-Respiratory Failure and Shock',
#   'number': 213,
#   'type': 'disease'},
#  'HCC221': {'descr': 'Heart Transplant Status/Complications',
#   'number': 221,
#   'type': 'disease'},
#  'HCC222': {'descr': 'End-Stage Heart Failure',
#   'number': 222,
#   'type': 'disease'},
#  'HCC223': {'descr': 'Heart Failure with Heart Assist Device/Artificial Heart',
#   'number': 223,
#   'type': 'disease'},
#  'HCC224': {'descr': 'Acute on Chronic Heart Failure',
#   'number': 224,
#   'type': 'disease'},
#  'HCC225': {'descr': 'Acute Heart Failure (Excludes Acute on Chronic)',
#   'number': 225,
#   'type': 'disease'},
#  'HCC226': {'descr': 'Heart Failure, Except End-Stage and Acute',
#   'number': 226,
#   'type': 'disease'},
#  'HCC227': {'descr': 'Cardiomyopathy/Myocarditis',
#   'number': 227,
#   'type': 'disease'},
#  'HCC228': {'descr': 'Acute Myocardial Infarction',
#   'number': 228,
#   'type': 'disease'},
#  'HCC229': {'descr': 'Unstable Angina and Other Acute Ischemic Heart Disease',
#   'number': 229,
#   'type': 'disease'},
#  'HCC238': {'descr': 'Specified Heart Arrhythmias',
#   'number': 238,
#   'type': 'disease'},
#  'HCC248': {'descr': 'Intracranial Hemorrhage',
#   'number': 248,
#   'type': 'disease'},
#  'HCC249': {'descr': 'Ischemic or Unspecified Stroke',
#   'number': 249,
#   'type': 'disease'},
#  'HCC253': {'descr': 'Hemiplegia/Hemiparesis',
#   'number': 253,
#   'type': 'disease'},
#  'HCC254': {'descr': 'Monoplegia, Other Paralytic Syndromes',
#   'number': 254,
#   'type': 'disease'},
#  'HCC263': {'descr': 'Atherosclerosis of Arteries of the Extremities with Ulceration or Gangrene',
#   'number': 263,
#   'type': 'disease'},
#  'HCC264': {'descr': 'Vascular Disease with Complications',
#   'number': 264,
#   'type': 'disease'},
#  'HCC267': {'descr': 'Deep Vein Thrombosis and Pulmonary Embolism',
#   'number': 267,
#   'type': 'disease'},
#  'HCC276': {'descr': 'Lung Transplant Status/Complications',
#   'number': 276,
#   'type': 'disease'},
#  'HCC277': {'descr': 'Cystic Fibrosis', 'number': 277, 'type': 'disease'},
#  'HCC278': {'descr': 'Idiopathic Pulmonary Fibrosis and Lung Involvement in Systemic Sclerosis',
#   'number': 278,
#   'type': 'disease'},
#  'HCC279': {'descr': 'Severe Persistent Asthma',
#   'number': 279,
#   'type': 'disease'},
#  'HCC280': {'descr': 'Chronic Obstructive Pulmonary Disease, Interstitial Lung Disorders, and Other Chronic Lung Disorders',
#   'number': 280,
#   'type': 'disease'},
#  'HCC282': {'descr': 'Aspiration and Specified Bacterial Pneumonias',
#   'number': 282,
#   'type': 'disease'},
#  'HCC283': {'descr': 'Empyema, Lung Abscess',
#   'number': 283,
#   'type': 'disease'},
#  'HCC298': {'descr': 'Severe Diabetic Eye Disease, Retinal Vein Occlusion, and Vitreous Hemorrhage',
#   'number': 298,
#   'type': 'disease'},
#  'HCC300': {'descr': 'Exudative Macular Degeneration',
#   'number': 300,
#   'type': 'disease'},
#  'HCC326': {'descr': 'Chronic Kidney Disease, Stage 5',
#   'number': 326,
#   'type': 'disease'},
#  'HCC327': {'descr': 'Chronic Kidney Disease, Severe (Stage 4)',
#   'number': 327,
#   'type': 'disease'},
#  'HCC328': {'descr': 'Chronic Kidney Disease, Moderate (Stage 3B)',
#   'number': 328,
#   'type': 'disease'},
#  'HCC329': {'descr': 'Chronic Kidney Disease, Moderate (Stage 3, Except 3B)',
#   'number': 329,
#   'type': 'disease'},
#  'HCC379': {'descr': 'Pressure Ulcer of Skin with Necrosis Through to Muscle, Tendon, or Bone',
#   'number': 379,
#   'type': 'disease'},
#  'HCC380': {'descr': 'Chronic Ulcer of Skin, Except Pressure, Through to Bone or Muscle',
#   'number': 380,
#   'type': 'disease'},
#  'HCC381': {'descr': 'Pressure Ulcer of Skin with Full Thickness Skin Loss',
#   'number': 381,
#   'type': 'disease'},
#  'HCC382': {'descr': 'Pressure Ulcer of Skin with Partial Thickness Skin Loss',
#   'number': 382,
#   'type': 'disease'},
#  'HCC383': {'descr': 'Chronic Ulcer of Skin, Except Pressure, Not Specified as Through to Bone or Muscle',
#   'number': 383,
#   'type': 'disease'},
#  'HCC385': {'descr': 'Severe Skin Burn', 'number': 385, 'type': 'disease'},
#  'HCC387': {'descr': 'Pemphigus, Pemphigoid, and Other Specified Autoimmune Skin Disorders',
#   'number': 387,
#   'type': 'disease'},
#  'HCC397': {'descr': 'Major Head Injury with Loss of Consciousness > 1 Hour',
#   'number': 397,
#   'type': 'disease'},
#  'HCC398': {'descr': 'Major Head Injury with Loss of Consciousness < 1 Hour or Unspecified',
#   'number': 398,
#   'type': 'disease'},
#  'HCC399': {'descr': 'Major Head Injury without Loss of Consciousness',
#   'number': 399,
#   'type': 'disease'},
#  'HCC401': {'descr': 'Vertebral Fractures without Spinal Cord Injury',
#   'number': 401,
#   'type': 'disease'},
#  'HCC402': {'descr': 'Hip Fracture/Dislocation',
#   'number': 402,
#   'type': 'disease'},
#  'HCC405': {'descr': 'Traumatic Amputations and Complications',
#   'number': 405,
#   'type': 'disease'},
#  'HCC409': {'descr': 'Amputation Status, Lower Limb/Amputation Complications',
#   'number': 409,
#   'type': 'disease'},
#  'HCC454': {'descr': 'Stem Cell, Including Bone Marrow, Transplant Status/Complications',
#   'number': 454,
#   'type': 'disease'},
#  'HCC463': {'descr': 'Artificial Openings for Feeding or Elimination',
#   'number': 463,
#   'type': 'disease'}}

# %%
import json
with open(file_path / "v28_category.json", "w") as json_file:
    json.dump(cat_dict, json_file)

# %% [markdown]
# ## Hierarchy Definition Files
#
# CMS provides a SAS file that contains the hieararchy definitions: The name of the hierarchy, and what categories are dropped by the "higher" category.
#
# The code below reads in that file, and parses it to a YAML. It assumes the file contents look like the below.
# ```sas
# %MACRO V24H86H1;
#  %**********************************************************************
#  1  MACRO NAME: V24H86H1
#  2  PURPOSE:    HCC HIERARCHIES: version 24 of HCCs,
#                 only 86 CMS HCCs are included
#  3  COMMENT:    it is assumed that:
#                  -MAX number of CCs are placed into global macro
#                   variable N_CC in the main program
#                  -the following arrays are set in the main program
#                   ARRAY C(&N_CC)   CC1-CC&N_CC
#                   ARRAY HCC(&N_CC) HCC1-HCC&N_CC
#                  -format ICD to CC creates only 86 out of &N_CC CMS CCs
#  **********************************************************************;
#  %* set to 0 HCCs in HIER parameter;
#  %MACRO SET0( CC=, HIER= );
#      IF HCC&CC=1 THEN DO I = &HIER; HCC(I) = 0; END;
#  %MEND SET0;
#
#  %*to copy CC into HCC;
#   DO K=1 TO &N_CC;
#      HCC(K)=C(K);
#   END;
#
#  %*imposing hierarchies;
#  /*Neoplasm 1 */   %SET0(CC=8     , HIER=%STR(9, 10, 11, 12 ));
#  /*Neoplasm 2 */   %SET0(CC=9     , HIER=%STR(10, 11, 12 ));
#  /*Neoplasm 3 */   %SET0(CC=10    , HIER=%STR(11, 12 ));
#  /*Neoplasm 4 */   %SET0(CC=11    , HIER=%STR(12 ));
#  /*Diabetes 1 */   %SET0(CC=17    , HIER=%STR(18, 19 ));
#
# ```
# Note: It was discovered for V28, the hierarchies sometimes spanned multiple lines, see below. This needed to be manual edited to one line
# for the code to work.
# ```sas
#  /*Spinal 2 */     %SET0(CC=181   , HIER=%STR(182, 254 ));
#  /*Neuro 2 */      %SET0(CC=191   , HIER=%STR(
# 180, 181, 182, 192, 253, 254 ));
#  /*Neuro 3 */      %SET0(CC=192   , HIER=%STR(180, 181, 182, 253, 254
# ));
#  /*Neuro 6 */      %SET0(CC=195   , HIER=%STR(196 ));
# ```

# %%
import re
import json
from pathlib import Path

hier_dict = {}
# This assumes the file is in the current directory, change to the appropriate location
file_path = Path.cwd() / 'cms_files'
# Will need to change the below as appropriate
input_file_name = 'V28115H1.TXT'
output_file_name = 'v28_hierarchy_definition.yaml'

with open(file_path / input_file_name, mode="r") as file:
    h_lines = file.readlines()
for line in h_lines:
    cc = re.search(r'CC=\d+', line)
    hier = re.search(r'HIER=%STR', line)
    if cc and hier:
        # Get Category Number
        number = cc[0].split('=')[1]
        # Get the Drop Numbers
        drop_string = line.split('HIER=')[1]
        s = re.search(r'\((.*?)\)', drop_string)
        drop_list_s = re.findall(r'\d+', s[0])
        drop_numbers = ['HCC'+str(eval(i)) for i in drop_list_s]
        # Get the hierarchy name
        hier_descr = re.search(r'\*(.*?)\*', line)[0].replace('*', '').strip()
        # Populate the dict
        hier_dict['HCC'+number] = {'descr': hier_descr, 'remove_code': drop_numbers}


import json
with open(file_path / 'v28_hierarchy.json', "w") as json_file:
    json.dump(hier_dict, json_file)
