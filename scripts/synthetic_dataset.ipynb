# %% [markdown]
# # Create Synthetic Dataset for Risk Adjustment
#
# Purpose is to create a synthetic dataset for testing the risk adjustment scoring model. At its core it needs a member id and an icd10 code.
#
# Since the purpose is to score categories, it pulls icd10s from the CMS files not the full ICD10 set.
#
# ## How it works
# It uses faker to generate IDs. From there it imports the appropriate icd10 list and creates a dictionary of member_id and dx code list. It then dumps to a json

# %%
from faker import Faker
import random
import pandas as pd
import numpy as np
import json

fake = Faker()

# Function to generate synthetic IDs
def generate_ids(num_records):
    ids = [fake.uuid4() for _ in range(num_records)]
    return ids

def generate_gender():
    # https://stackoverflow.com/questions/43991548/when-defining-a-python-class-how-to-set-a-random-variable-in-it
   return random.choice(('M', 'F'))
    
def generate_age():
    # Will need to refactor this for test data to at least have one member per each bucket
    return random.randint(1, 100)

def generate_orec():
    # https://resdac.org/cms-data/variables/current-reason-entitlement-code
    # Might want to add 2 and 3 to ensure performs
    return random.choice(('0', '1', '2', '3'))

def generate_medicaid():
    # https://resdac.org/cms-data/variables/current-reason-entitlement-code
    # Might want to add 2 and 3 to ensure performs
    return random.choice((True, False))


# Function to generate synthetic ICD-10 codes
def generate_icd10_codes():
    df = pd.read_csv(r"...\F2423P2M.TXT", sep='\t', header=None)
    df.rename({0: 'icd10', 1: 'cat_nbr', 2: 'unknown'}, axis=1, inplace=True)
    # Set the random seed for reproducibility
    np.random.seed(42)
    
    # Randomly sample with replacement using numpy
    icd_codes = np.random.choice(df['icd10'], size=random.randint(1, 25), replace=True)
    
    return list(icd_codes)

def generate_json(input_dict, type):
    # Specify the file path where you want to save the JSON file
    json_file_path = f'test_dataset_{type}.json'
    
    # Dump the dictionary to JSON file
    with open(json_file_path, 'w') as json_file:
        json.dump(input_dict, json_file)

def generate_pipe_delimited_dx_codes(input_dict):
    '''Expects a nested dictionary of member_id, dx_code'''
    data_list = []
    for key, value in input_dict.items():
        tmp_list = [(key, dx) for dx in value]
        data_list.extend(tmp_list)  

    df = pd.DataFrame(data_list, columns=['member_id', 'dx_code'])
    df.to_csv('test_dataset_10k.txt', sep='|', header=True, index=False)

def generate_pipe_delimited_demo(input_dict):
    df = pd.DataFrame.from_dict(test_demo_dict, orient='index').reset_index().rename({'index': 'member_id'}, axis=1)
    df.to_csv('test_demo_dataset_10k.txt', sep='|', header=True, index=False)


# Set the number of records you want
num_records = 10000

# Generate synthetic IDs and ICD-10 codes
synthetic_ids = generate_ids(num_records)

test_dx_dict = {}
test_demo_dict = {}
for id in synthetic_ids:
    icd_codes = generate_icd10_codes()
    gender = generate_gender()
    orec = generate_orec()
    age = generate_age()
    medicaid = generate_medicaid
    # icd_codes = generate_icd10_codes()
    test_dx_dict[id] = icd_codes
    test_demo_dict[id] = {
        'gender': gender,
        'orec': orec,
        'age': age,
        'medicaid': medicaid
    }

# generate_json(test_dx_dict, 'dx_10k')
# generate_json(test_demo_dict, 'demo_10k')
generate_pipe_delimited_dx_codes(test_dx_dict)
generate_pipe_delimited_demo(test_demo_dict)

# %%
test_demo_dict
# Out:
# {'587790b1-ee73-470f-8b48-91c23e403484': {'gender': 'F',
#   'orec': '0',
#   'age': 77},
#  'bfd6477a-b7a1-463f-bec6-5a89be66c71b': {'gender': 'F',
#   'orec': '0',
#   'age': 90},
#  'f4514062-c1f4-4f55-af86-8afa10b20d7d': {'gender': 'M',
#   'orec': '1',
#   'age': 70},
#  '4482263e-57c5-4d15-a56f-ce2453494e1f': {'gender': 'M',
#   'orec': '1',
#   'age': 67},
#  '371c11ab-c648-40f8-8df5-350389603d68': {'gender': 'F',
#   'orec': '1',
#   'age': 66},
#  '15e01924-6e34-4ff7-b2e2-dc0b78934591': {'gender': 'F',
#   'orec': '1',
#   'age': 62},
#  'fc4231cd-b4cf-45fe-9956-b21944e66b66': {'gender': 'F',
#   'orec': '1',
#   'age': 69},
#  '0f323acf-6cf2-4928-aec5-639cb2052142': {'gender': 'F',
#   'orec': '1',
#   'age': 68},
#  '080eb6e2-bb39-4a95-9367-9ec668ee62cf': {'gender': 'F',
#   'orec': '1',
#   'age': 32},
#  '9e418033-29fe-4caf-af21-fc4431bdfe89': {'gender': 'M',
#   'orec': '1',
#   'age': 18},
#  '99b1bd63-df33-49e2-ace6-dc3f5cd9ea52': {'gender': 'F',
#   'orec': '0',
#   'age': 88},
#  '30f99117-e47f-441f-a72f-9c5bdd0f11d6': {'gender': 'F',
#   'orec': '1',
#   'age': 41},
#  'e5a77931-1585-45df-b652-188f78f52287': {'gender': 'F',
#   'orec': '0',
#   'age': 86},
#  '5a598aa6-005a-4dbc-aceb-f8012e4e354d': {'gender': 'F',
#   'orec': '0',
#   'age': 34},
#  '2b0ff1bb-c9ca-4c9c-8aad-1ec42a1b320a': {'gender': 'F',
#   'orec': '0',
#   'age': 26},
#  '66772294-68dc-4e44-bf03-c5689047f6a3': {'gender': 'M',
#   'orec': '0',
#   'age': 91},
#  'a79d2a48-cae7-4ce6-966f-03f6d806a6b7': {'gender': 'M',
#   'orec': '0',
#   'age': 51},
#  'abc8e8e2-7499-49de-9e24-4ff72c05c3db': {'gender': 'F',
#   'orec': '0',
#   'age': 34},
#  'eff66a12-0bc4-441c-b6e3-b1fb7bd499f6': {'gender': 'F',
#   'orec': '1',
#   'age': 37},
#  '5b0ab7a4-4e04-4be8-a5d9-0edc3ff063ec': {'gender': 'M',
#   'orec': '1',
#   'age': 11},
#  '6b77fedd-7e96-4d2e-85c5-4676b3f39eb0': {'gender': 'F',
#   'orec': '1',
#   'age': 100},
#  '846302cf-069e-44b8-8a2e-8720e90d051e': {'gender': 'F',
#   'orec': '0',
#   'age': 78},
#  '8cc5d8b0-74e4-4adc-b726-40e098defca3': {'gender': 'M',
#   'orec': '0',
#   'age': 100},
#  '55288b67-ea0f-4277-98e1-1a7a7664721a': {'gender': 'F',
#   'orec': '1',
#   'age': 24},
#  '94bb99ed-d416-4bad-881e-a8d12529149e': {'gender': 'M',
#   'orec': '1',
#   'age': 99},
#  'ed2a146f-ddc9-471d-bea7-b610fae3b1ed': {'gender': 'F',
#   'orec': '0',
#   'age': 71},
#  '3a5d5808-5cb0-4637-ab74-03988969f025': {'gender': 'F',
#   'orec': '0',
#   'age': 10},
#  'cd347d80-668b-45a0-b14f-3819d003aae7': {'gender': 'M',
#   'orec': '0',
#   'age': 61},
#  'd45818c1-0da1-4572-84fe-0d8334702adc': {'gender': 'M',
#   'orec': '0',
#   'age': 86},
#  '3bef35a2-12e9-4398-8463-9312c7b640fa': {'gender': 'F',
#   'orec': '0',
#   'age': 40},
#  'cad6cae4-4a49-4273-9641-bce9901ab86c': {'gender': 'M',
#   'orec': '0',
#   'age': 84},
#  '3ba2ab63-6db7-45fe-be6e-cbde1bc95f12': {'gender': 'F',
#   'orec': '0',
#   'age': 5},
#  '08a65176-0a45-4334-8845-3f1aa138a964': {'gender': 'F',
#   'orec': '1',
#   'age': 95},
#  'de7e291d-1687-4fd8-97a8-656761bdcde8': {'gender': 'M',
#   'orec': '0',
#   'age': 6},
#  '58e72a1e-ea8c-4770-984f-ad5572d5e9f4': {'gender': 'F',
#   'orec': '0',
#   'age': 15},
#  '507c7919-5eb0-4670-a4a6-bf1ee0495458': {'gender': 'M',
#   'orec': '1',
#   'age': 83},
#  'f7970862-5a9b-4d37-9bc5-1006ac79a2f6': {'gender': 'F',
#   'orec': '1',
#   'age': 85},
#  '85a2ddb0-0195-4cec-85ca-8cf2f872b52d': {'gender': 'F',
#   'orec': '1',
#   'age': 72},
#  '607df14f-5794-480e-aca0-5b82700e0563': {'gender': 'F',
#   'orec': '1',
#   'age': 18},
#  'aa7f2892-d964-4a06-bfa7-01f53476882e': {'gender': 'F',
#   'orec': '0',
#   'age': 45},
#  '33116d9d-a000-4597-a880-47cf09c589ec': {'gender': 'M',
#   'orec': '1',
#   'age': 95},
#  'b79c6fb6-ac9d-4527-a950-b1301ec560a9': {'gender': 'F',
#   'orec': '0',
#   'age': 76},
#  '0ebb57c7-d3da-434b-a9c1-4b5024a6c571': {'gender': 'M',
#   'orec': '0',
#   'age': 1},
#  'a0b30786-c20a-4025-ba0b-56411220b419': {'gender': 'F',
#   'orec': '1',
#   'age': 93},
#  '0936db2e-090e-4162-80c8-6a055ee02260': {'gender': 'F',
#   'orec': '1',
#   'age': 49},
#  'dfeeae00-ec45-49f0-b1b3-673262f73774': {'gender': 'F',
#   'orec': '1',
#   'age': 31},
#  'f17f627e-8cb1-4e61-ab98-d9ec3e0ae49f': {'gender': 'M',
#   'orec': '0',
#   'age': 41},
#  '19d4b958-4d87-4d67-b71e-ff7026b4d289': {'gender': 'M',
#   'orec': '1',
#   'age': 17},
#  '0b5d9353-f114-470f-b161-e93bddd3882e': {'gender': 'F',
#   'orec': '1',
#   'age': 97},
#  'a61875d2-6345-49b2-8b2b-0ca83aba5dff': {'gender': 'M',
#   'orec': '0',
#   'age': 88},
#  'cec1b4d4-e1b4-4431-9688-a77661ded819': {'gender': 'F',
#   'orec': '1',
#   'age': 81},
#  '7c8f3379-b26d-41a8-8a7e-790fe4ccd340': {'gender': 'F',
#   'orec': '0',
#   'age': 9},
#  '78438b1f-6cce-4ddd-85d5-42192b8f876a': {'gender': 'F',
#   'orec': '0',
#   'age': 44},
#  'e3e6aaa1-d95c-4e71-b62b-e6598753eaa5': {'gender': 'F',
#   'orec': '0',
#   'age': 18},
#  'f840c94e-6d59-4e67-9faf-ea2b56f55201': {'gender': 'F',
#   'orec': '1',
#   'age': 51},
#  'e065223a-c750-4462-b536-a8150ea5da59': {'gender': 'M',
#   'orec': '1',
#   'age': 79},
#  'ec53480b-534c-4004-8fb6-8eddc4a2dc7a': {'gender': 'M',
#   'orec': '1',
#   'age': 26},
#  '2da65613-41d1-4484-831f-70eba9961fcf': {'gender': 'M',
#   'orec': '0',
#   'age': 18},
#  '89998d48-8a63-471f-95d3-04bc832256c6': {'gender': 'M',
#   'orec': '1',
#   'age': 30},
#  '3d5330ac-348e-4bfb-a9b8-652039dbb3bd': {'gender': 'M',
#   'orec': '0',
#   'age': 3},
#  '28590f29-eed5-4a45-b043-136e2ea7c665': {'gender': 'M',
#   'orec': '1',
#   'age': 99},
#  'a0ed1027-9160-4bfa-8971-d10c1aba4b16': {'gender': 'M',
#   'orec': '0',
#   'age': 48},
#  '1fd8e48d-8df0-4c81-b33a-5f3dcfda1bf3': {'gender': 'F',
#   'orec': '1',
#   'age': 28},
#  '699983eb-c84f-476d-b75c-091dcd5d8604': {'gender': 'F',
#   'orec': '0',
#   'age': 17},
#  '945dfbba-dda5-44e9-a922-1ef16bf9b8be': {'gender': 'M',
#   'orec': '1',
#   'age': 78},
#  '5d79ef78-626a-4068-9a9b-e4d8d4230563': {'gender': 'F',
#   'orec': '1',
#   'age': 77},
#  'd907b428-13bc-4041-8b9a-65812aee22c4': {'gender': 'F',
#   'orec': '0',
#   'age': 11},
#  'd79d05bc-9b53-466e-a270-e412bb40e1ea': {'gender': 'M',
#   'orec': '1',
#   'age': 37},
#  'a52633a1-64e2-4b38-8ed1-bc07d67db5ce': {'gender': 'F',
#   'orec': '1',
#   'age': 33},
#  'f944b9a5-8497-41bb-82da-7b03a298efa3': {'gender': 'M',
#   'orec': '0',
#   'age': 40},
#  '690c1e21-194b-45ca-9a96-b6abdc15861f': {'gender': 'F',
#   'orec': '1',
#   'age': 84},
#  '43c7b3d4-565d-4ecd-af6a-735b9fc9b7d1': {'gender': 'M',
#   'orec': '0',
#   'age': 64},
#  'd39862c4-45b6-4724-9455-6f6fffce7102': {'gender': 'M',
#   'orec': '0',
#   'age': 65},
#  '7a169e59-c87d-45eb-ac1c-74103ed20da9': {'gender': 'M',
#   'orec': '1',
#   'age': 14},
#  'd5d3ac0a-8701-4d83-adcb-9c85817cb67d': {'gender': 'F',
#   'orec': '0',
#   'age': 94},
#  '4b9e8bb2-5e40-413f-b5fd-f926f1c3f86c': {'gender': 'M',
#   'orec': '1',
#   'age': 11},
#  '376e1475-fb3f-4a81-9016-ab17f466f11a': {'gender': 'F',
#   'orec': '0',
#   'age': 45},
#  '13c88282-1fdb-4bc1-9163-8de5b81756f9': {'gender': 'M',
#   'orec': '0',
#   'age': 29},
#  'f7aad70d-2ea3-4b39-abd2-01b9f7c6fd0a': {'gender': 'M',
#   'orec': '1',
#   'age': 40},
#  '17608960-afd0-4398-81a7-75cec72b5a63': {'gender': 'M',
#   'orec': '1',
#   'age': 71},
#  '7d7882e0-299a-4120-ad01-a97ebeaf3ef3': {'gender': 'M',
#   'orec': '0',
#   'age': 55},
#  '5e709c27-9062-41ec-9f68-9a0040b52eb0': {'gender': 'F',
#   'orec': '1',
#   'age': 87},
#  'eabe1f9a-d7b8-4d29-b52b-74ddb441aa6a': {'gender': 'F',
#   'orec': '1',
#   'age': 41},
#  '52054435-8c93-4751-8af1-7f01023fb978': {'gender': 'M',
#   'orec': '0',
#   'age': 8},
#  'd5571d03-8134-4445-a6ae-4731c98c7128': {'gender': 'M',
#   'orec': '1',
#   'age': 18},
#  '930891d8-ed1c-452b-8377-c35c1d780b10': {'gender': 'F',
#   'orec': '0',
#   'age': 25},
#  '0267edcc-0276-4f6a-a178-4109e161b5b2': {'gender': 'F',
#   'orec': '1',
#   'age': 65},
#  '3490ed96-319e-428d-962f-32339f83c694': {'gender': 'F',
#   'orec': '0',
#   'age': 18},
#  '245077b9-3542-414d-b9fe-23d9ee5efbee': {'gender': 'M',
#   'orec': '0',
#   'age': 27},
#  'd65ad7d6-44f7-464c-8ec0-0cd25f5f8fc3': {'gender': 'M',
#   'orec': '0',
#   'age': 58},
#  '8240dfe2-b751-4805-808e-a9e28e06fd06': {'gender': 'M',
#   'orec': '0',
#   'age': 25},
#  'ad3e34a1-1c6e-4414-ba34-3ec9d29759cd': {'gender': 'F',
#   'orec': '1',
#   'age': 98},
#  'e6e9cfc7-f9a0-40e8-b1a0-47c3ca695d32': {'gender': 'M',
#   'orec': '1',
#   'age': 9},
#  'cce4bf89-9787-4608-84da-231d48d76f80': {'gender': 'F',
#   'orec': '1',
#   'age': 42},
#  'c92d77c9-4a00-4a09-882c-f17eed394b43': {'gender': 'F',
#   'orec': '1',
#   'age': 81},
#  'd5137a49-a2f1-4e13-a10a-df9016343547': {'gender': 'F',
#   'orec': '0',
#   'age': 4},
#  '9c658b9e-62f1-4b86-8122-e6d82e499bbb': {'gender': 'M',
#   'orec': '1',
#   'age': 52},
#  '99a16292-92f9-4d83-99c4-a965e86b8d44': {'gender': 'F',
#   'orec': '1',
#   'age': 68},
#  '459399c4-e393-463f-8abb-4a13188578ed': {'gender': 'F',
#   'orec': '1',
#   'age': 70},
#  '2332463d-1480-42b6-842b-a6b7a1ee28e9': {'gender': 'M',
#   'orec': '1',
#   'age': 30}}

# %%
df_demo = pd.DataFrame.from_dict(test_demo_dict, orient='index').reset_index().rename({'index': 'member_id'}, axis=1)

# %%
df_demo
# Out:
#                                member_id gender orec  age
# 0   587790b1-ee73-470f-8b48-91c23e403484      F    0   77
# 1   bfd6477a-b7a1-463f-bec6-5a89be66c71b      F    0   90
# 2   f4514062-c1f4-4f55-af86-8afa10b20d7d      M    1   70
# 3   4482263e-57c5-4d15-a56f-ce2453494e1f      M    1   67
# 4   371c11ab-c648-40f8-8df5-350389603d68      F    1   66
# ..                                   ...    ...  ...  ...
# 95  d5137a49-a2f1-4e13-a10a-df9016343547      F    0    4
# 96  9c658b9e-62f1-4b86-8122-e6d82e499bbb      M    1   52
# 97  99a16292-92f9-4d83-99c4-a965e86b8d44      F    1   68
# 98  459399c4-e393-463f-8abb-4a13188578ed      F    1   70
# 99  2332463d-1480-42b6-842b-a6b7a1ee28e9      M    1   30
#
# [100 rows x 4 columns]

# %%
test_dict2 = test_dict

# %%
test_dict2.

# %%
import numpy as np
import random
random.randint(0, 1)
# Out:
# 1

# %% [markdown]
# ### Future Enhancements
#
# 1. Add Gender
# 2. Add Age or DOB
# 3. OREC
# 4. Name
# 5. Address
# 6. DX Code Dates
# 7. Provider
# 8. Specialty
